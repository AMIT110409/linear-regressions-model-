# %% [markdown]
# <a href="https://colab.research.google.com/github/AMIT110409/linear-regressions-model-/blob/main/Linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Regrssion is used  for prediction of continous variable 

## import the library 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('Salary_Data.csv')

# %%
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
df.shape
# Out:
# (30, 2)

# %%
## statiscal value 

df.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes

# %%
df.isnull().any()
# Out:
# YearsExperience    False
# Salary             False
# dtype: bool

# %%
plt.scatter(df.YearsExperience,df.Salary)
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.title('Experience vs Salary ')
# Out:
# Text(0.5, 1.0, 'Experience vs Salary ')

# %%
X =df.iloc[:,0:1]
X.head()
# Out:
#    YearsExperience
# 0              1.1
# 1              1.3
# 2              1.5
# 3              2.0
# 4              2.2

# %%
y =df.iloc[:,1:]
y.head()
# Out:
#     Salary
# 0  39343.0
# 1  46205.0
# 2  37731.0
# 3  43525.0
# 4  39891.0

# %%
## splitting the dataset into train and test 

from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=20,random_state=0)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (10, 1)
# (20, 1)
# (10, 1)
# (20, 1)

# %%
# Model building 

from sklearn.linear_model import LinearRegression
lr= LinearRegression()

# %%
#train the model 

lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
## test the model 

y_pred=lr.predict(X_test)

# %%
y_pred
# Out:
# array([[ 39306.98862067],
#        [123578.74414986],
#        [ 64205.4618452 ],
#        [ 62290.19467408],
#        [115917.67546539],
#        [108256.60678091],
#        [116875.30905094],
#        [ 63247.82825964],
#        [ 75697.06487191],
#        [100595.53809644],
#        [ 52713.85881849],
#        [ 73781.79770079],
#        [ 55586.75957517],
#        [ 68035.99618744],
#        [103468.43885312],
#        [ 90061.56865529],
#        [ 37391.72144955],
#        [125494.01132097],
#        [ 53671.49240405],
#        [ 46010.42371958]])

# %%
y_test
# Out:
#       Salary
# 2    37731.0
# 28  122391.0
# 13   57081.0
# 10   63218.0
# 26  116969.0
# 24  109431.0
# 27  112635.0
# 11   55794.0
# 17   83088.0
# 22  101302.0
# 5    56642.0
# 16   66029.0
# 8    64445.0
# 14   61111.0
# 23  113812.0
# 20   91738.0
# 1    46205.0
# 29  121872.0
# 6    60150.0
# 4    39891.0

# %%
E = y_test-y_pred
E
# Out:
#           Salary
# 2   -1575.988621
# 28  -1187.744150
# 13  -7124.461845
# 10    927.805326
# 26   1051.324535
# 24   1174.393219
# 27  -4240.309051
# 11  -7453.828260
# 17   7390.935128
# 22    706.461904
# 5    3928.141182
# 16  -7752.797701
# 8    8858.240425
# 14  -6924.996187
# 23  10343.561147
# 20   1676.431345
# 1    8813.278550
# 29  -3622.011321
# 6    6478.507596
# 4   -6119.423720

# %%
##accuracy 

from sklearn.metrics import r2_score
acc=r2_score(y_pred,y_test)
acc
# Out:
# 0.9586482350056668

# %%
## predict with random values 

y_pr = lr.predict([[5]])
y_pr
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[72824.16411523]])

# %%
plt.scatter(X_train,y_train)
plt.plot(X_train,lr.predict(X_train),'r')

# %%
plt.scatter(X_test,y_test)
plt.plot(X_test,y_pred,'r')
